# %% [markdown]
# Simple fusion reactor systems code, based on the approach in Plasma Physics and Fusion Energy, Freidberg
# Section 5.5
# Adapted and expanded by Richard Kembleton for TU/e Fusion Reactor Design Masterclass
# 2021
# Additional plasma equations from Iter Physics Design Guidelines 1989 (Uckan)
# and Iter Physics Basis Nucl. Fusion 39 (1999)
# Radiation equations from
# Matthews et al, Nuc. Fus. 39 (1999)
# Johner, Fus. Sci. Tech. 59 (2011)
# Uckan (1989)

# %%
from IPython import embed
# from simplesystemcode_trian import InputParameters, simplesystemcode
from driehoek import InputParameters, simplesystemcode

# using this for comparison against the original code
import simplesystemcode as SSC

from utilities import plot_scan, write_csv
import os

import matplotlib.pyplot as plt

# %%
# Assumed inputs/targets: have a play!
input_parameters = InputParameters(
	GrossElecPower=1000.0,
	WallLoad=4.0,
	BMax=13.0,
	SigmaMax=300.0,
	Li6=0.075,
	NeutShield=0.99,
	BlktSupport=0.3,
	ThermalEff=0.4,
	Kappa=1.8,
	Delta=0.0,
	PlasmaT=15.0,
	SafetyFac=3.5,
	GamCD=0.5,
	ElectEffCD=0.5,
	PowerRecirc=0.05,
	ZEff=1.0
)

# %%
# # EU DEMO
# input_parameters = InputParameters(
# 	GrossElecPower=500.0,
#     # Neutron wall load in MW/m^2
# 	WallLoad=1.0,
#     # Maximum magnetic field on the TF superconductor in Tesla
# 	BMax=12.0,
#     # Maximum stress on the TF structure in MPa
# 	SigmaMax=300.0,
# 	# Fractional concentration of Li6 in breeder material (7.5% in natural lithium)
# 	Li6=0.075,
# 	# Neutron shielding efficiency target for blanket and vacuum vessel
# 	NeutShield=0.99,
# 	# Blanket/shield structural support thickness in meters
# 	BlktSupport=0.3,
# 	# Thermal efficiency of electricity generation (Pe/Pth)
# 	ThermalEff=0.4,
# 	# Plasma elongation
# 	Kappa=1.0,
# 	# Plasma temperature in keV
# 	PlasmaT=15.0,
# 	# Plasma safety factor (q_edge)
# 	SafetyFac=3.5,
# 	# Current drive efficiency (gamma_CD)
# 	GamCD=0.5,
# 	# Electrical efficiency of the CD system
# 	ElectEffCD=0.5,
# 	# Fraction of extracted heat representing coolant pumping power.
# 	PowerRecirc=0.05,
# 	# Plasma effective charge number
# 	ZEff=1.05
# )

# %%
## Do a single run of the systems code
design_point = simplesystemcode(input_parameters)
# Out:
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.206416225413433 / 23.6625553769985
# 	Bpol_old / Bpol : 	1.78137086611352 / 1.6727982300309985
# Simple systems code fusion power plant:
#
# M	ajor radius: 3.76 m
# Minor radius: 1.98 m
# Aspect ratio: 1.90
# Plasma elongation: 1.80
# Stable elongation: 2.01
# Bootstrap current fraction: 0.17
# Plasma volume: 524.41 m3
# Plasma surface area: 420.41 m2
#
# Fusion power: 1960.00 MW
# CD power for steady-state: 195.11 MW
# CD electrical power: 390.23 MW
# Coolant pumping power: 125.00 MW
# Net elec power: 484.77 MW
#
# H factor: 0.76 (IPB98(y,2))
# n / nG: 1.24
# Divertor power loading: 46.28 MW T m-1
# Field in plasma: 2.04 T
# Normalised beta: 6.54 % m T MA-1
# Line radiation: 0.00 MW
# Bremsstrahlung radiation: 19.01 MW
# Synchrotron radiation: 1.06 MW
# Plasma ZEff: 1.00
#
# Magnet thickness: 0.80 m
# Blanket/shield thickness: 1.19 m
# Bore: -0.21 m
# Wall load: 3.73 MW m-2

# %%
## Sample code for a triangularity scan, focusing on negative triangularity
# triangularities = [-0.7, -0.6, -0.5, -0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2, 0.3]
triangularities = [-0.8]
for x in range(15):
	triangularities.append(triangularities[0] + (x+1) * 0.1)
scan_out = []
scan_og = []

for triangularity in triangularities:
	input_parameters.Delta = triangularity
	scan_out.append(simplesystemcode(input_parameters, print_out=False))
	scan_og.append(SSC.simplesystemcode(input_parameters, print_out=False))
# Out:
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.634856916790282 / 23.93009683226608
# 	Bpol_old / Bpol : 	1.8015119939967137 / 1.6653466076813788
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.634856916790282 / 23.106621976481044
# 	Bpol_old / Bpol : 	1.7395189381453398 / 1.6125470772184098
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.655269749241109 / 22.528498251010987
# 	Bpol_old / Bpol : 	1.6959964721583207 / 1.5768654982604173
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.696095414142762 / 22.174940051908177
# 	Bpol_old / Bpol : 	1.6693798086017915 / 1.5564743238003793
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.757333911495241 / 22.034463265091198
# 	Bpol_old / Bpol : 	1.6588043973068534 / 1.5504230873464437
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.838985241298548 / 22.10382598341421
# 	Bpol_old / Bpol : 	1.6640261801467222 / 1.558423149990357
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.941049403552682 / 22.387783564943636
# 	Bpol_old / Bpol : 	1.685403151267951 / 1.5807738244518794
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.063526398257645 / 22.899619241284928
# 	Bpol_old / Bpol : 	1.7239353024893775 / 1.618372512685849
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.206416225413433 / 23.6625553769985
# 	Bpol_old / Bpol : 	1.78137086611352 / 1.6727982300309985
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.369718885020045 / 24.71232802917801
# 	Bpol_old / Bpol : 	1.8604001336140659 / 1.7464811089432613
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.55343437707749 / 26.101479226641317
# 	Bpol_old / Bpol : 	1.9649785881538198 / 1.842993301291233
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.757562701585757 / 27.906396350753926
# 	Bpol_old / Bpol : 	2.1008568451475256 / 1.9675315096334178
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 10.982103858544855 / 30.239032150690495
# 	Bpol_old / Bpol : 	2.2764629616069345 / 2.127725691404442
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 11.227057847954775 / 33.267084657004695
# 	Bpol_old / Bpol : 	2.5044216258285315 / 2.3350395976319986
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 11.492424669815527 / 37.250462466820856
# 	Bpol_old / Bpol : 	2.8042993468132744 / 2.607318446338893
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 11.7782043241271 / 42.611490000956245
# 	Bpol_old / Bpol : 	3.207889665339243 / 2.973737733144321

# %%
def run_results(scans, folder_out="custom_trian_out",xparam='Delta'):
    os.makedirs(folder_out, exist_ok=True)

    ## Sample code for visualising a scan

    plot_scan(scans, xparam, 'NetElecPower', f"{folder_out}/trian_netelec.png")
    plt.close()
    plot_scan(scans, xparam, 'RMajor',f"{folder_out}/trian_major.png")
    plt.close()
    plot_scan(scans, xparam, 'DivLoad',f"{folder_out}/trian_divload.png")
    plt.close()
    plot_scan(scans, xparam, 'FusPower',f"{folder_out}/trian_fuspower.png")
    plt.close()
    plot_scan(scans, xparam, 'PlasVol',f"{folder_out}/trian_plasmavol.png")
    plt.close()
    plot_scan(scans, xparam, 'PlasSurf',f"{folder_out}/trian_surface.png")
    plt.close()
    plot_scan(scans, xparam, 'RMinor',f"{folder_out}/trian_minor.png")
    plt.close()
    plot_scan(scans, xparam, 'BMax',f"{folder_out}/trian_bmax.png")
    plt.close()
    plot_scan(scans, xparam, 'betaN',f"{folder_out}/trian_betaN.png")
    plt.close()
    plot_scan(scans, xparam, 'BootFrac',f"{folder_out}/trian_bootfrac.png")
    plt.close()
    plot_scan(scans, xparam, 'MagField',f"{folder_out}/trian_magfield.png")
    plt.close()

# def run_result_double(scans, scans_og, folder_out="custom_double"):
#     os.makedirs(folder_out, exist_ok=True)

#     ## Sample code for visualising a scan

#     plot_scan(scans, 'Delta', 'NetElecPower', f"{folder_out}/trian_netelec.png")
#     plot_scan(scan_og, 'Delta', 'NetElecPower', f"{folder_out}/trian_netelec.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'RMajor',f"{folder_out}/trian_major.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'RMinor',f"{folder_out}/trian_minor.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'BMax',f"{folder_out}/trian_bmax.png")
#     plt.close()

# %%
# plotting the results
run_results(scan_out, "custom_trian_out")
run_results(scan_og, "custom_reference_out") # doing it against the reference
# run_result_double(scan_out, scan_og)

# %%
## Sample code for exporting scan data to .csv for Mimer (https://assar.his.se/mimer/html/). Be careful with overwriting data!
write_csv(scan_out, filename = 'triangularity_scan_output.csv')

# %%
# LOOPING OVER WALL LOAD PARAMETER

wall_load_runs = []
input_parameters.Delta = -0.8
for x in range (39):
    wall_load = 1 + x * 0.1
    input_parameters.WallLoad = wall_load
    wall_load_runs.append(simplesystemcode(input_parameters, print_out=False))

run_results(wall_load_runs, "custom_wallload_out","WallLoad")
# Out:
# 	Ip_old / Ip  / Sauter: 	9.088600255743357 / 8.57963864142173 / 21.309250905146857
# 	Bpol_old / Bpol : 	1.6042087651290178 / 1.4829563355242463
# 	Ip_old / Ip  / Sauter: 	9.725648448957967 / 9.181012135816323 / 22.80288242220056
# 	Bpol_old / Bpol : 	1.7166527352242673 / 1.586901346590707
# 	Ip_old / Ip  / Sauter: 	10.320526152345145 / 9.742576687813818 / 24.19764045783364
# 	Bpol_old / Bpol : 	1.821653285265015 / 1.683965540666429
# 	Ip_old / Ip  / Sauter: 	10.87449809963802 / 10.265526206058292 / 25.496490323280952
# 	Bpol_old / Bpol : 	1.9194336506101881 / 1.774355280100896
# 	Ip_old / Ip  / Sauter: 	11.388675461739279 / 10.75090963588188 / 26.702037284358745
# 	Bpol_old / Bpol : 	2.0101899615825527 / 1.8582518709130358
# 	Ip_old / Ip  / Sauter: 	11.864018269510604 / 11.19963324641801 / 27.816532241968442
# 	Bpol_old / Bpol : 	2.094091671109927 / 1.935811958109622
# 	Ip_old / Ip  / Sauter: 	12.301336668156072 / 11.612461814739332 / 28.841874673140328
# 	Bpol_old / Bpol : 	2.1712817761336254 / 2.0071677303587965
# 	Ip_old / Ip  / Sauter: 	12.701290969502883 / 11.990018675210722 / 29.779612753611648
# 	Bpol_old / Bpol : 	2.241876826836417 / 2.0724269285205397
# 	Ip_old / Ip  / Sauter: 	13.064390450281296 / 12.332784585065545 / 30.63094054025803
# 	Bpol_old / Bpol : 	2.3059667145295673 / 2.131672649566049
# 	Ip_old / Ip  / Sauter: 	13.390990824420117 / 12.64109533825259 / 31.396692044604475
# 	Bpol_old / Bpol : 	2.3636142254932957 / 2.1849629341406933
# 	Ip_old / Ip  / Sauter: 	13.681290294863235 / 12.915138038350895 / 32.07733197586281
# 	Bpol_old / Bpol : 	2.414854344091632 / 2.232330122352201
# 	Ip_old / Ip  / Sauter: 	13.93532406483771 / 13.154945917206799 / 32.672942871979146
# 	Bpol_old / Bpol : 	2.4596932839684627 / 2.2737799581927307
# 	Ip_old / Ip  / Sauter: 	14.152957159097038 / 13.360391558187604 / 33.183208268227034
# 	Bpol_old / Bpol : 	2.498107220941028 / 2.30929041820528
# 	Ip_old / Ip  / Sauter: 	14.333875371498566 / 13.531178350694647 / 33.60739147277919
# 	Bpol_old / Bpol : 	2.530040695176799 / 2.3388102344303388
# 	Ip_old / Ip  / Sauter: 	14.47757411521889 / 13.666829964766633 / 33.94430942477689
# 	Bpol_old / Bpol : 	2.5554046431696156 / 2.362257075133038
# 	Ip_old / Ip  / Sauter: 	14.583344904577624 / 13.766677589921278 / 34.192300999437286
# 	Bpol_old / Bpol : 	2.5740740116762417 / 2.3795153390877997
# 	Ip_old / Ip  / Sauter: 	14.650259141108464 / 13.829844629206391 / 34.34918899266385
# 	Bpol_old / Bpol : 	2.5858848958315725 / 2.390433510006085
# 	Ip_old / Ip  / Sauter: 	14.677148809051522 / 13.855228475744637 / 34.41223485944544
# 	Bpol_old / Bpol : 	2.5906311317525996 / 2.3948210066848072
# 	Ip_old / Ip  / Sauter: 	14.66258360417038 / 13.841478922336838 / 34.378085089781955
# 	Bpol_old / Bpol : 	2.5880602595964097 / 2.3924444511923313
# 	Ip_old / Ip  / Sauter: 	14.604843921361933 / 13.786972661765667 / 34.24270787508146
# 	Bpol_old / Bpol : 	2.5778687556628377 / 2.383023261347632
# 	Ip_old / Ip  / Sauter: 	14.501889006683598 / 13.689783222309318 / 34.00131843698704
# 	Bpol_old / Bpol : 	2.559696410979097 / 2.3662244541936794
# 	Ip_old / Ip  / Sauter: 	14.351319432779402 / 13.547645544543757 / 33.6482910467706
# 	Bpol_old / Bpol : 	2.5331197079200964 / 2.3416565232389313
# 	Ip_old / Ip  / Sauter: 	14.150332876361418 / 13.357914235285179 / 33.177055340637985
# 	Bpol_old / Bpol : 	2.497644014589313 / 2.3088622228177083
# 	Ip_old / Ip  / Sauter: 	13.895671953561525 / 13.11751432416208 / 32.57997401381322
# 	Bpol_old / Bpol : 	2.45269437735191 / 2.2673100565599937
# 	Ip_old / Ip  / Sauter: 	13.583562592208242 / 12.822883087044582 / 31.848198327373563
# 	Bpol_old / Bpol : 	2.3976046430613787 / 2.2163842218031187
# 	Ip_old / Ip  / Sauter: 	13.209641074607267 / 12.46990117442926 / 30.971497051799552
# 	Bpol_old / Bpol : 	2.3316045815418103 / 2.1553727054076437
# 	Ip_old / Ip  / Sauter: 	12.768867450892516 / 12.053810873642536 / 29.938053454786584
# 	Bpol_old / Bpol : 	2.2538046023696543 / 2.0834531557050684
# 	Ip_old / Ip  / Sauter: 	12.25542247609542 / 11.569118817434077 / 28.734223658551006
# 	Bpol_old / Bpol : 	2.1631775634633668 / 1.9996760660660695
# 	Ip_old / Ip  / Sauter: 	11.66258453021394 / 11.00947979652196 / 27.344248065015883
# 	Bpol_old / Bpol : 	2.058537046516528 / 1.9029446923621198
# 	Ip_old / Ip  / Sauter: 	10.98258209512785 / 10.367557497800691 / 25.749905471259112
# 	Bpol_old / Bpol : 	1.9385113180238671 / 1.7919909821199311
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.634856916790282 / 23.93009683226608
# 	Bpol_old / Bpol : 	1.8015119939967137 / 1.6653466076813788
# 	Ip_old / Ip  / Sauter: 	9.323645981270008 / 8.801521806318888 / 21.860342184165823
# 	Bpol_old / Bpol : 	1.6456961672025865 / 1.5213079560157923
# 	Ip_old / Ip  / Sauter: 	8.322127881145542 / 7.8560887198013925 / 19.512169761452892
# 	Bpol_old / Bpol : 	1.468920418523383 / 1.3578936160811874
# 	Ip_old / Ip  / Sauter: 	7.187697928794328 / 6.785186844781846 / 16.852370473472366
# 	Bpol_old / Bpol : 	1.2686846922533577 / 1.172792496248725
# 	Ip_old / Ip  / Sauter: 	5.903781466400686 / 5.573169704282248 / 13.84208316095628
# 	Bpol_old / Bpol : 	1.0420634321353592 / 0.9633001653491081
# 	Ip_old / Ip  / Sauter: 	4.450911711857565 / 4.201660655993542 / 10.43566575223658
# 	Bpol_old / Bpol : 	0.785620599438864 / 0.7262402940196636
# 	Ip_old / Ip  / Sauter: 	2.806131945574092 / 2.648988556621943 / 6.579293622623463
# 	Bpol_old / Bpol : 	0.4953041542732386 / 0.4578671115363871
# 	Ip_old / Ip  / Sauter: 	0.9422483388474989 / 0.889482431872039 / 2.209207766044163
# 	Bpol_old / Bpol : 	0.16631417397329287 / 0.15374349233239645
# 	Ip_old / Ip  / Sauter: 	-1.1731104741819935 / -1.107416287627802 / -2.7504901448386248
# 	Bpol_old / Bpol : 	-0.2070631397786667 / -0.19141249048319509
# c:\Users\quint\Documents\TUE 2025 - 2026\simple-fusion-systems-code\driehoek.py:126: RuntimeWarning: invalid value encountered in scalar power
#   PTauE = 0.0562 * PlasCur**0.93 * MagField**0.15 * (10.0*PlasmaDens)**0.41 * PlasHeat**(-0.69) * RMajor**1.97 * inputs.Kappa**0.78 * InvAspect**0.58 * 2.5**0.19 # Prediction from IPB98(y,2), s
# c:\Users\quint\Documents\TUE 2025 - 2026\simple-fusion-systems-code\driehoek.py:151: RuntimeWarning: invalid value encountered in scalar power
#   Lambda0 = 77.7 * ((PlasmaDens * RMinor)/MagField)**0.5 # Lambda factor for synchrotron radiation

# %%
# LOOPING OVER KAPPA PARAMETER

kappa_runs = []
input_parameters.Delta = -0.8
input_parameters.WallLoad = 4
for x in range (25):
    kappa = 0.8 + x * 0.05
    input_parameters.Kappa = kappa
    kappa_runs.append(simplesystemcode(input_parameters, print_out=False))

run_results(kappa_runs, "custom_kappa_out","Kappa")
# Out:
# 	Ip_old / Ip  / Sauter: 	5.675295570296434 / 5.357479018359834 / 4.490556230692141
# 	Bpol_old / Bpol : 	0.5070888951690775 / 0.4818717701459755
# 	Ip_old / Ip  / Sauter: 	5.96185203545572 / 5.6279883214702 / 5.019961801256217
# 	Bpol_old / Bpol : 	0.5499458182605835 / 0.5256584992080438
# 	Ip_old / Ip  / Sauter: 	6.254166687030773 / 5.9039333525570505 / 5.601313397635346
# 	Bpol_old / Bpol : 	0.5963449861169607 / 0.5725151912429256
# 	Ip_old / Ip  / Sauter: 	6.55107006636721 / 6.184210142650646 / 6.236906752744804
# 	Bpol_old / Bpol : 	0.6463033437756558 / 0.6224237206498522
# 	Ip_old / Ip  / Sauter: 	6.851197160116443 / 6.467530119149923 / 6.928660444590123
# 	Bpol_old / Bpol : 	0.6998069200436914 / 0.6753279233117818
# 	Ip_old / Ip  / Sauter: 	7.152992680326335 / 6.752425090228061 / 7.678027734765316
# 	Bpol_old / Bpol : 	0.7568049805143648 / 0.7311298580216855
# 	Ip_old / Ip  / Sauter: 	7.454713103103171 / 7.037249169329394 / 8.485898467872627
# 	Bpol_old / Bpol : 	0.8172039235570699 / 0.7896857566472815
# 	Ip_old / Ip  / Sauter: 	7.754426071429386 / 7.32017821142934 / 9.352490538810658
# 	Bpol_old / Bpol : 	0.8808608574819926 / 0.8508016731310722
# 	Ip_old / Ip  / Sauter: 	8.050007582925534 / 7.599207158281705 / 10.27723028393415
# 	Bpol_old / Bpol : 	0.9475768005899698 / 0.9142288271057658
# 	Ip_old / Ip  / Sauter: 	8.339137253812279 / 7.872145567598792 / 11.25862101537778
# 	Bpol_old / Bpol : 	1.0170894470122809 / 0.9796586274653979
# 	Ip_old / Ip  / Sauter: 	8.6192918572905 / 8.136611513282233 / 12.294098787180442
# 	Bpol_old / Bpol : 	1.0890654407296887 / 1.0467173532716085
# 	Ip_old / Ip  / Sauter: 	8.887737266022082 / 8.390023979124846 / 13.379874351546961
# 	Bpol_old / Bpol : 	1.1630920983067612 / 1.1149604629733922
# 	Ip_old / Ip  / Sauter: 	9.141518876522124 / 8.629593819436886 / 14.510760129414887
# 	Bpol_old / Bpol : 	1.2386685179119217 / 1.1838664974572886
# 	Ip_old / Ip  / Sauter: 	9.377450552835958 / 8.852313321877144 / 15.679980878099844
# 	Bpol_old / Bpol : 	1.3151960082461418 / 1.252830537494334
# 	Ip_old / Ip  / Sauter: 	9.592102094308915 / 9.054944377027617 / 16.878966587309673
# 	Bpol_old / Bpol : 	1.391967766139144 / 1.321157171403915
# 	Ip_old / Ip  / Sauter: 	9.781785205085715 / 9.234005233600916 / 18.097125970625587
# 	Bpol_old / Bpol : 	1.4681577258108887 / 1.3880529239865191
# 	Ip_old / Ip  / Sauter: 	9.942537919439024 / 9.38575579595044 / 19.32159874010703
# 	Bpol_old / Bpol : 	1.5428084961231003 / 1.4526180928124894
# 	Ip_old / Ip  / Sauter: 	10.070107415840999 / 9.506181400553904 / 20.53698465439937
# 	Bpol_old / Bpol : 	1.6148182945179395 / 1.5138379326500135
# 	Ip_old / Ip  / Sauter: 	10.159931132897057 / 9.590974989454823 / 21.725047112883196
# 	Bpol_old / Bpol : 	1.6829267776924202 / 1.5705731230502384
# 	Ip_old / Ip  / Sauter: 	10.207116081117547 / 9.635517580574966 / 22.864388827058633
# 	Bpol_old / Bpol : 	1.7456996593000962 / 1.6215494477686596
# 	Ip_old / Ip  / Sauter: 	10.206416225413433 / 9.634856916790282 / 23.93009683226608
# 	Bpol_old / Bpol : 	1.8015119939967137 / 1.6653466076813788
# 	Ip_old / Ip  / Sauter: 	10.15220779367011 / 9.583684157224583 / 24.893353804407923
# 	Bpol_old / Bpol : 	1.8485299948237435 / 1.7003860810427376
# 	Ip_old / Ip  / Sauter: 	10.038462346340763 / 9.47630845494568 / 25.721012313510826
# 	Bpol_old / Bpol : 	1.8846912370994482 / 1.7249179362115141
# 	Ip_old / Ip  / Sauter: 	9.858717420305991 / 9.306629244768857 / 26.375128274196445
# 	Bpol_old / Bpol : 	1.9076830864832084 / 1.7370064922212043
# 	Ip_old / Ip  / Sauter: 	9.60604453688351 / 9.068106042818036 / 26.812449437245963
# 	Bpol_old / Bpol : 	1.9149191714894247 / 1.7345147116480062

# %%
## Option to look at scan embedded in IPython, by typing e.g. "scan_out[3]", "scan_out[5]"
# embed()
