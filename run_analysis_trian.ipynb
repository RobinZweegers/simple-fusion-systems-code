# %% [markdown]
# Simple fusion reactor systems code, based on the approach in Plasma Physics and Fusion Energy, Freidberg
# Section 5.5
# Adapted and expanded by Richard Kembleton for TU/e Fusion Reactor Design Masterclass
# 2021
# Additional plasma equations from Iter Physics Design Guidelines 1989 (Uckan)
# and Iter Physics Basis Nucl. Fusion 39 (1999)
# Radiation equations from
# Matthews et al, Nuc. Fus. 39 (1999)
# Johner, Fus. Sci. Tech. 59 (2011)
# Uckan (1989)

# %%
from IPython import embed
# from simplesystemcode_trian import InputParameters, simplesystemcode
from driehoek import InputParameters, simplesystemcode

# using this for comparison against the original code
import simplesystemcode as SSC

from utilities import plot_scan, write_csv
import os

import matplotlib.pyplot as plt

# %%
# Assumed inputs/targets: have a play!
input_parameters = InputParameters(
	GrossElecPower=1000.0,
	WallLoad=2.0,
	BMax=13.0,
	SigmaMax=300.0,
	Li6=0.075,
	NeutShield=0.99,
	BlktSupport=0.3,
	ThermalEff=0.4,
	Kappa=1.8,
	Delta=0.0,
	PlasmaT=15.0,
	SafetyFac=3.5,
	GamCD=0.5,
	ElectEffCD=0.5,
	PowerRecirc=0.05,
	ZEff=1.0
)

# %%
# # EU DEMO
# input_parameters = InputParameters(
# 	GrossElecPower=500.0,
#     # Neutron wall load in MW/m^2
# 	WallLoad=1.0,
#     # Maximum magnetic field on the TF superconductor in Tesla
# 	BMax=12.0,
#     # Maximum stress on the TF structure in MPa
# 	SigmaMax=300.0,
# 	# Fractional concentration of Li6 in breeder material (7.5% in natural lithium)
# 	Li6=0.075,
# 	# Neutron shielding efficiency target for blanket and vacuum vessel
# 	NeutShield=0.99,
# 	# Blanket/shield structural support thickness in meters
# 	BlktSupport=0.3,
# 	# Thermal efficiency of electricity generation (Pe/Pth)
# 	ThermalEff=0.4,
# 	# Plasma elongation
# 	Kappa=1.0,
# 	# Plasma temperature in keV
# 	PlasmaT=15.0,
# 	# Plasma safety factor (q_edge)
# 	SafetyFac=3.5,
# 	# Current drive efficiency (gamma_CD)
# 	GamCD=0.5,
# 	# Electrical efficiency of the CD system
# 	ElectEffCD=0.5,
# 	# Fraction of extracted heat representing coolant pumping power.
# 	PowerRecirc=0.05,
# 	# Plasma effective charge number
# 	ZEff=1.05
# )

# %%
## Do a single run of the systems code
design_point = simplesystemcode(input_parameters)
# Out:
# 	Ip_old / Ip : 	13.681290294863235 / 13.681290294863235
# 	Bpol_old / Bpol : 	1.0299585802893296 / 0.9671837138956757
# Simple systems code fusion power plant:
#
# M	ajor radius: 7.53 m
# Minor radius: 1.98 m
# Aspect ratio: 3.80
# Plasma elongation: 1.80
# Stable elongation: 1.64
# Bootstrap current fraction: 0.24
# Plasma volume: 1048.81 m3
# Plasma surface area: 840.82 m2
#
# Fusion power: 1960.00 MW
# CD power for steady-state: 147.04 MW
# CD electrical power: 294.09 MW
# Coolant pumping power: 125.00 MW
# Net elec power: 580.91 MW
#
# H factor: 0.67 (IPB98(y,2))
# n / nG: 1.51
# Divertor power loading: 36.26 MW T m-1
# Field in plasma: 7.52 T
# Normalised beta: 2.17 % m T MA-1
# Line radiation: 0.00 MW
# Bremsstrahlung radiation: 19.01 MW
# Synchrotron radiation: 37.11 MW
# Plasma ZEff: 1.00
#
# Magnet thickness: 0.80 m
# Blanket/shield thickness: 1.19 m
# Bore: 3.56 m
# Wall load: 1.86 MW m-2

# %%
## Sample code for a triangularity scan, focusing on negative triangularity
# triangularities = [-0.7, -0.6, -0.5, -0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2, 0.3]
triangularities = [-0.8]
for x in range(15):
	triangularities.append(triangularities[0] + (x+1) * 0.1)
scan_out = []
scan_og = []

for triangularity in triangularities:
	input_parameters.Delta = triangularity
	scan_out.append(simplesystemcode(input_parameters, print_out=False))
	scan_og.append(SSC.simplesystemcode(input_parameters, print_out=False))
# Out:
# 	Ip_old / Ip : 	13.681290294863235 / 12.915138038350895
# 	Bpol_old / Bpol : 	0.9722808997931272 / 0.8987920722035654
# 	Ip_old / Ip : 	13.681290294863235 / 12.915138038350895
# 	Bpol_old / Bpol : 	0.9722808997931272 / 0.9013116723341453
# 	Ip_old / Ip : 	13.681290294863235 / 12.94250061894062
# 	Bpol_old / Bpol : 	0.9743408169537058 / 0.9059007156105361
# 	Ip_old / Ip : 	13.681290294863235 / 12.997225780120074
# 	Bpol_old / Bpol : 	0.978460651274863 / 0.9122842343671838
# 	Ip_old / Ip : 	13.681290294863235 / 13.079313521889253
# 	Bpol_old / Bpol : 	0.984640402756599 / 0.9203069485748011
# 	Ip_old / Ip : 	13.681290294863235 / 13.188763844248157
# 	Bpol_old / Bpol : 	0.9928800713989135 / 0.9298695578790189
# 	Ip_old / Ip : 	13.681290294863235 / 13.32557674719679
# 	Bpol_old / Bpol : 	1.0031796572018068 / 0.9409025621758258
# 	Ip_old / Ip : 	13.681290294863235 / 13.48975223073515
# 	Bpol_old / Bpol : 	1.015539160165279 / 0.9533540266820344
# 	Ip_old / Ip : 	13.681290294863235 / 13.681290294863235
# 	Bpol_old / Bpol : 	1.0299585802893296 / 0.9671837138956757
# 	Ip_old / Ip : 	13.681290294863235 / 13.900190939581044
# 	Bpol_old / Bpol : 	1.0464379175739584 / 0.9823607414898041
# 	Ip_old / Ip : 	13.681290294863235 / 14.146454164888585
# 	Bpol_old / Bpol : 	1.0649771720191668 / 0.9988637056363493
# 	Ip_old / Ip : 	13.681290294863235 / 14.420079970785848
# 	Bpol_old / Bpol : 	1.085576343624953 / 1.016683105813782
# 	Ip_old / Ip : 	13.681290294863235 / 14.721068357272841
# 	Bpol_old / Bpol : 	1.1082354323913184 / 1.0358266492327255
# 	Ip_old / Ip : 	13.681290294863235 / 15.049419324349557
# 	Bpol_old / Bpol : 	1.1329544383182621 / 1.0563291134777915
# 	Ip_old / Ip : 	13.681290294863235 / 15.405132872016004
# 	Bpol_old / Bpol : 	1.159733361405785 / 1.0782708306315683
# 	Ip_old / Ip : 	13.681290294863235 / 15.788209000272172
# 	Bpol_old / Bpol : 	1.188572201653886 / 1.1018153282559358

# %%
def run_results(scans, folder_out="custom_trian_out"):
    os.makedirs(folder_out, exist_ok=True)

    ## Sample code for visualising a scan

    plot_scan(scans, 'Delta', 'NetElecPower', f"{folder_out}/trian_netelec.png")
    plt.close()
    plot_scan(scans, 'Delta', 'RMajor',f"{folder_out}/trian_major.png")
    plt.close()
    plot_scan(scans, 'Delta', 'DivLoad',f"{folder_out}/trian_divload.png")
    plt.close()
    plot_scan(scans, 'Delta', 'FusPower',f"{folder_out}/trian_fuspower.png")
    plt.close()
    plot_scan(scans, 'Delta', 'PlasVol',f"{folder_out}/trian_plasmavol.png")
    plt.close()
    plot_scan(scans, 'Delta', 'PlasSurf',f"{folder_out}/trian_surface.png")
    plt.close()
    plot_scan(scans, 'Delta', 'RMinor',f"{folder_out}/trian_minor.png")
    plt.close()
    plot_scan(scans, 'Delta', 'BMax',f"{folder_out}/trian_bmax.png")
    plt.close()
    plot_scan(scans, 'Delta', 'betaN',f"{folder_out}/trian_betaN.png")
    plt.close()
    plot_scan(scans, 'Delta', 'BootFrac',f"{folder_out}/trian_bootfrac.png")
    plt.close()
    plot_scan(scans, 'Delta', 'MagField',f"{folder_out}/trian_magfield.png")
    plt.close()

# def run_result_double(scans, scans_og, folder_out="custom_double"):
#     os.makedirs(folder_out, exist_ok=True)

#     ## Sample code for visualising a scan

#     plot_scan(scans, 'Delta', 'NetElecPower', f"{folder_out}/trian_netelec.png")
#     plot_scan(scan_og, 'Delta', 'NetElecPower', f"{folder_out}/trian_netelec.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'RMajor',f"{folder_out}/trian_major.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'RMinor',f"{folder_out}/trian_minor.png")
#     plt.close()
#     plot_scan(scans, 'Delta', 'BMax',f"{folder_out}/trian_bmax.png")
#     plt.close()

# %%
# plotting the results
run_results(scan_out, "custom_trian_out")
run_results(scan_og, "custom_reference_out") # doing it against the reference
# run_result_double(scan_out, scan_og)

# %%
## Sample code for exporting scan data to .csv for Mimer (https://assar.his.se/mimer/html/). Be careful with overwriting data!
write_csv(scan_out, filename = 'triangularity_scan_output.csv')

# %%
## Option to look at scan embedded in IPython, by typing e.g. "scan_out[3]", "scan_out[5]"
# embed()
